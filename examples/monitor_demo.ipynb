# %% [markdown]
# # peetsfea monitor demo
#
# This notebook launches a minimal monitor UI placeholder.

# %%
import peetsfea
from peetsfea import config
from peetsfea.types import AedtMachine

this_pc = AedtMachine(name="this_pc", is_current_pc=True, ip_address="localhost")

config.machine_list.append(this_pc)

peetsfea.start_monitor()
# Out:
# MonitorHandle(backend='dearpygui', text='peetsfea monitor\nstatus: idle\njobs: 0\nnote: this is a placeholder UI', root=None)
